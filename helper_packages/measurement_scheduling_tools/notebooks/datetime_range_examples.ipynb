# %%
from datetime import datetime, timedelta, timezone
from measurement_scheduling_tools import datetime_range

# %%
# Simplest usage
start = datetime(2022, 1, 20, 10, 0, 0, microsecond=0, tzinfo=timezone.utc)
end = start + timedelta(hours=1)

datetime_range(start, end, timedelta(minutes=10))
# Out:
# [datetime.datetime(2022, 1, 20, 10, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 10, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 20, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 40, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 50, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 11, 0, tzinfo=datetime.timezone.utc)]

# %%
# Exclude the start point
datetime_range(start, end, timedelta(minutes=10), include_start_point=False)
# Out:
# [datetime.datetime(2022, 1, 20, 10, 10, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 20, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 40, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 50, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 11, 0, tzinfo=datetime.timezone.utc)]

# %%
# Exclude the end point
datetime_range(start, end, timedelta(minutes=10), include_end_point=False)
# Out:
# [datetime.datetime(2022, 1, 20, 10, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 10, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 20, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 40, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 20, 10, 50, tzinfo=datetime.timezone.utc)]

# %%
# Intervals are aligned with the origin, which is the start of the Unix
# epoch by default.
#
# Here, we advance the start and end times by 2 s and the intervals stay
# aligned to :10, :20, etc.
datetime_range(
    datetime(2022, 1, 1, 0, 0, 2, tzinfo=timezone.utc),
    datetime(2022, 1, 1, 0, 1, 2, tzinfo=timezone.utc),
    timedelta(seconds=10)
)
# Out:
# [datetime.datetime(2022, 1, 1, 0, 0, 10, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 0, 0, 20, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 0, 0, 30, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 0, 0, 40, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 0, 0, 50, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 0, 1, tzinfo=datetime.timezone.utc)]

# %%
# A different origin can be specified. Here, the origin is set to the start
# datetime.
start = datetime(2022, 1, 1, 0, 0, 2, tzinfo=timezone.utc)
datetime_range(
    start,
    datetime(2022, 1, 1, 0, 1, 2, tzinfo=timezone.utc),
    timedelta(seconds=10),
    origin=start
)
# Out:
# [datetime.datetime(2022, 1, 1, 0, 0, 2, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 0, 0, 12, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 0, 0, 22, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 0, 0, 32, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 0, 0, 42, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 0, 0, 52, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 0, 1, 2, tzinfo=datetime.timezone.utc)]

# %%
# Everything works fine if time zones are different
datetime_range(
    datetime(2022, 1, 1, 0, 0, 0, tzinfo=timezone.utc),
    datetime(2022, 1, 1, 0, 1, 0, tzinfo=timezone(timedelta(hours=-7))),
    timedelta(hours=1)
)
# Out:
# [datetime.datetime(2022, 1, 1, 0, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 1, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 2, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 3, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 4, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 5, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 6, 0, tzinfo=datetime.timezone.utc),
#  datetime.datetime(2022, 1, 1, 7, 0, tzinfo=datetime.timezone.utc)]

# %%
# Everything works fine if time zones are absent, but a tz-naive origin must
# be specified
datetime_range(
    datetime(2022, 1, 1, 0, 0, 0),
    datetime(2022, 1, 1, 0, 1, 0),
    timedelta(seconds=10),
    origin=datetime(1970, 1, 1, 0, 0, 0)
)
# Out:
# [datetime.datetime(2022, 1, 1, 0, 0),
#  datetime.datetime(2022, 1, 1, 0, 0, 10),
#  datetime.datetime(2022, 1, 1, 0, 0, 20),
#  datetime.datetime(2022, 1, 1, 0, 0, 30),
#  datetime.datetime(2022, 1, 1, 0, 0, 40),
#  datetime.datetime(2022, 1, 1, 0, 0, 50),
#  datetime.datetime(2022, 1, 1, 0, 1)]
